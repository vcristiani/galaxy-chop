# %%
import galaxychop as gchop
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 import galaxychop as gchop
#
# File ~/proyectos/galaxychop/src/galaxychop/__init__.py:21, in <module>
#      11 """
#      12 GalaxyChop.
#      13
#      14 Implementation of a few galaxy dynamic decomposition methods.
#      15 """
#      17 # =============================================================================
#      18 # IMPORTS
#      19 # =============================================================================
# ---> 21 from . import constants, models, preproc, utils
#      22 from .config import config
#      23 from .core import (
#      24     Galaxy,
#      25     NoGravitationalPotentialError,
#    (...)
#      28     mkgalaxy,
#      29 )
#
# File ~/proyectos/galaxychop/src/galaxychop/constants.py:19, in <module>
# ...
