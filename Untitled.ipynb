# %%
import galaxychop as gchop
import numpy as np
#gal = gchop.read_hdf5("/home/juanbc/Descargas/galaxy_TNG_17234.h5")
# gal = gchop.read_hdf5("/home/juanbc/Descargas/galaxy_TNG_20.h5")
# gal = gchop.read_hdf5("/home/juanbc/Descargas/galaxy_TNG_60737.h5")
gal = gchop.read_hdf5("tests/datasets/gal394242.h5")
gal                     
gal = gchop.preproc.center_and_align(gal)
id(gal.stars), id(gal.stars.copy())
comps = gchop.models.JHistogram().decompose(gal)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 10
#       8 gal = gchop.preproc.center_and_align(gal)
#       9 id(gal.stars), id(gal.stars.copy())
# ---> 10 comps = gchop.models.JHistogram().decompose(gal)
#
# File ~/misc/proyectos/galaxychop/src/galaxychop/models/abc.py:463, in GalaxyDecomposerABC.decompose(self, galaxy)
#     459 component_labels = self.get_lmap().copy()
#     461 cls_name = type(self).__name__
# --> 463 return dgalaxy.DecomposedGalaxy(
#     464     stars=galaxy.stars,
#     465     dark_matter=galaxy.dark_matter,
#     466     gas=galaxy.gas,
#     467     method=cls_name,
#     468     components=final_labels,
#     469     component_labels=component_labels,
#     470     probabilities=final_probs,
#     471 )
#
# File <attrs generated methods galaxychop.models.new_dgalaxy.DecomposedGalaxy>:41, in __init__(self, stars, dark_matter, gas, method, components, component_labels, probabilities)
#      39     __attr_validator_gas(self, __attr_gas, self.gas)
#      40     __attr_validator_component_labels(self, __attr_component_labels, self.component_labels)
# ---> 41 self.__attrs_post_init__()
#
# File ~/misc/proyectos/galaxychop/src/galaxychop/models/new_dgalaxy.py:55, in DecomposedGalaxy.__attrs_post_init__(self)
#      53 # Validate lengths match
#      54 if len(self.stars) != len(self.components):
# ---> 55     raise ValueError(
#      56         f"galaxy length ({len(self)}) must match "
#      57         f"components length ({len(self.components)})"
#      58     )
#      59 self.components.setflags(write=False)
#      61 # Validate probabilities
#
# ValueError: galaxy length (272647) must match components length (272647)

# %%
class DecomposedGalaxy:
# Out:
# <Galaxy stars=37393, dark_matter=155101, gas=80153, potential=True>
# <Components length=272647, labels=['Bulge', 'Cold disk', 'Halo', 'Warm disk', 'nan'], probabilities=True, lmap=True>

# %%
comps.components.to_dataframe()
# Out:
#                    m  labels ptypes  lmap   probs_0   probs_1       probs_2  \
# 0       5.224283e+05     0.0  stars  Halo  0.009790  0.990210  6.996590e-64
# 1       9.745897e+05     0.0  stars  Halo  0.000025  0.999975  6.967402e-32
# 2       6.935776e+05     0.0  stars  Halo  0.007637  0.992363  2.752671e-73
# 3       1.070959e+06     0.0  stars  Halo  0.027517  0.972482  8.708692e-50
# 4       6.013803e+05     0.0  stars  Halo  0.001511  0.997621  3.136419e-25
# ...              ...     ...    ...   ...       ...       ...           ...
# 272642  1.429845e+06     NaN    gas   NaN       NaN       NaN           NaN
# 272643  1.436841e+06     NaN    gas   NaN       NaN       NaN           NaN
# 272644  1.690580e+06     NaN    gas   NaN       NaN       NaN           NaN
# 272645  1.210975e+06     NaN    gas   NaN       NaN       NaN           NaN
# 272646  1.023048e+06     NaN    gas   NaN       NaN       NaN           NaN
#
#              probs_3
# 0       2.944842e-09
# 1       8.700127e-08
# 2       5.851009e-11
# 3       7.269839e-07
# 4       8.680271e-04
# ...              ...
# 272642           NaN
# 272643           NaN
# 272644           NaN
# 272645           NaN
# 272646           NaN
#
# [272647 rows x 8 columns]

# %%
gal.to_dataframe()
# Out:
#         ptype  ptypev             m           x           y           z  \
# 0       stars       0  5.224283e+05   -0.046686   -0.061851   -0.262750
# 1       stars       0  9.745897e+05   -0.156204   -0.125754   -0.183235
# 2       stars       0  6.935776e+05   -0.250791   -0.162875   -0.205813
# 3       stars       0  1.070959e+06   -0.224842   -0.253019   -0.378030
# 4       stars       0  6.013803e+05   -0.068880   -0.198297   -0.285537
# ...       ...     ...           ...         ...         ...         ...
# 272642    gas       2  1.429845e+06  -79.045700  293.427378 -178.989162
# 272643    gas       2  1.436841e+06 -150.039829  172.085208 -167.965517
# 272644    gas       2  1.690580e+06 -110.107475  279.408348 -182.051375
# 272645    gas       2  1.210975e+06 -158.195412  -87.566228  155.997798
# 272646    gas       2  1.023048e+06   50.397798   79.972812  -92.323497
#
#                 vx          vy          vz  softening      potential  \
# 0         5.939116   14.066256   -0.766770        0.0 -195699.620206
# 1        21.590183   -0.313959    5.223790        0.0 -196176.962277
# 2       -10.337991   -1.167629   20.345625        0.0 -195152.120168
# 3       -10.080818  -13.842422    3.846266        0.0 -194695.767625
# 4        16.760601   -0.438800  -11.421205        0.0 -195703.942688
# ...            ...         ...         ...        ...            ...
# 272642 -110.544679  -47.756487 -122.974827        0.0  -17314.963254
# 272643  -92.683490  -36.100685  -30.009193        0.0  -20910.620132
# 272644 -112.121055  -84.474389  -95.920897        0.0  -17358.735183
# 272645  -77.030400   20.322667   75.850186        0.0  -23427.833806
# 272646  -20.630830  118.908677 -165.368092        0.0  -37321.182177
#
#         kinetic_energy   total_energy            Jx            Jy  \
# 0           116.860299 -195582.759907      3.743340     -1.596302
# 1           246.761287 -195930.200990     -0.714443     -3.140089
# 2           261.090937 -194891.029232     -3.554104      7.230190
# 3           154.014651 -194541.752974     -6.206026      4.675652
# 4           205.777118 -195498.165569      2.139500     -5.572466
# ...                ...            ...           ...           ...
# 272642    14811.808049   -2503.155205 -44632.074442  10065.668260
# 272643     5397.020248  -15513.599884 -11227.808453  11065.056143
# 272644    14453.935944   -2904.799239 -42179.778204   9850.184449
# 272645     6049.972023  -17377.861783  -9812.205960    -17.421428
# 272646    20955.755194  -16365.426984  -2246.886412  10238.898089
#
#                   Jz
# 0          -0.289357
# 1           2.764102
# 2          -1.390968
# 3           0.561722
# 4           3.353806
# ...              ...
# 272642  36211.780228
# 272643  21365.998282
# 272644  40628.820337
# 272645  -9960.214204
# 272646   7642.640965
#
# [272647 rows x 16 columns]
